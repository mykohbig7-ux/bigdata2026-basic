# %% [markdown]
# # 클래스(class)와 객체지향 프로그래밍(OOP)

# %% [markdown]
# ## 1. 클래스란 무엇인가???
#
# **클래스(class)** 는 데이터와 그 데이터를 다루는 함수(메서드)를 하나로 묶어 새로운
# 타입을 정의하는 방법 (==설계도)
#
# | 용어 | 설명 | 비유 |
# |-----|-----|-----|
# | 클래스(class) | 설계도| 붕어빵 틀, 와플 틀, 과자 틀 |
# | 인스턴스(instance) | 클래스로 만든 실제 객체 | 붕어빵 한 개, 와플 1개, 과자 1개
# | 메서드(method) | 클래스 내부에서 만들어진 함수 | 붕어빵의 기능, 와플 기능, 과자 기능 |
# | 속성(attribite) | 인스턴스가 가진 데이터 (== 인스턴스 변수) | 붕어빵의 재료(맛), 게임
# 캐릭터의 머리 색깔 등

# %% [markdown]
# ## 2.클래스 기본 구조

# %%
# 클래스 정의의 기본 구조
# class 클래스이름: 로 시작한다.
#   파이썬에서 클래스이름을 첫글자는 대문자로 하는 것이 관행이다.
class Toy:

    # 메서드(함수) 정의
    # __init__ : 객체(인스턴스)가 처음 만들어질 때 자동으로 호출되는 '초기화 메서드" (생성자)
    # seif : 현재 만들어진 인스턴스(객체) 자기 자신을 가리킨다.
    def 

    # 메서드(함수) 정의 --> 인스턴스 메서드 정의
    def add(self, new_elems):
        """첫번째 매개변수 반드시 seif --> 호출한 인스턴스가 자동으로 전달된다
        new_elems 매개변수느 리스트이다.
        """
        seif.elems += new_elems # new_elems만큼 누적해라!

    # 메서드(함수) 정의 --> 인스턴스 메서드 정의
    def size(self):
        """
        저장된 요소 개수를 반환(리턴)한다.
        개수를 우리에게 알려준다.
        """
        return len(self.elems)
