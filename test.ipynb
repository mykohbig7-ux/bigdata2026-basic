# %% [markdown]
# # 실습 1

# %%
f = open('data1.txt', 'w', encoding='utf-8')
f.write('Life is too Short\nso, you need Python\nPython is easy\nand useful on many fields')
f.close()

# %% [markdown]
# # 실습 2

# %%
f = open('guest.txt', 'w', encoding='utf-8')
while True:
    name = input('name : ')
    print(f'name : {name}\n{name} welcome!!')
    count += 1
    if not name:
        break
    f.write(name)
f.close()
# Out:
# name : 정명식
# 정명식 welcome!!
# name : 최봉수
# 최봉수 welcome!!
# name : 김진영
# 김진영 welcome!!
# name : 김진호
# 김진호 welcome!!
# name :
#  welcome!!

# %% [markdown]
# # 실습 3

# %%
f = open('data2.txt', 'w', encoding='utf-8')

# %% [markdown]
# # 실습4

# %%
f = open('data3.txt', 'w', encoding='utf-8')
f.write('갑분싸, 혼코노, 퇴준생, 워라벨, 쉼포족, 올인빌, TMI, 가심비, 마상, 별다줄, 자만추, 팬아저, 톤그로, 인싸, 소확행')
# Out:
# 71

# %%
with open('data3.txt', 'r')as f:
    while True:
        line = f.readline()
        if not line:
            break
