# %% [markdown]
# # 2020년 건강검진 일부 데이터 -> 산점도 그래프

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import koreanize_matplotlib

# %%
# 데이터 불러오기
data = pd.read_excel('health_screenings_2020_1000ea.xlsx')

# %%
data.shape
# Out:
# (1000, 30)

# %%
data.head()
# Out:
#    year  city_code  gender  age_code  height  weight  waist  eye_left  \
# 0  2020         36       1         9     165      60   72.1       1.2
# 1  2020         27       2        13     150      65   81.0       0.8
# 2  2020         11       2        12     155      55   70.0       0.6
# 3  2020         31       1        13     160      70   90.8       1.0
# 4  2020         41       2        12     155      50   75.2       1.5
#
#    eye_right  hear_left  ...  serum   AST   ALT   GTP  smoking  drinking  \
# 0        1.5          1  ...    1.1  21.0  27.0  21.0        1         0
# 1        0.8          1  ...    0.5  18.0  15.0  15.0        1         0
# 2        0.7          1  ...    0.7  27.0  25.0   7.0        1         0
# 3        1.0          1  ...    1.2  65.0  97.0  72.0        1         0
# 4        1.2          1  ...    0.7  18.0  17.0  14.0        1         0
#
#    oral_check  dental_caries  tartar  open_date
# 0           0            NaN     NaN 2021-12-29
# ...

# %% [markdown]
# ## 키, 몸무게 데이터를 가지고 산점도 그래프 그리기

# %%
heightdata = data['height']  # 키
weightdata = data['weight']  # 몸무게

plt.figure(figsize=(10, 4))
plt.scatter(x=heightdata, y=weightdata)

plt.title('2020년 건강검진 산점도 그래프')
plt.xlabel('키')
plt.ylabel('몸무게')
plt.grid()
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 30 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   year           1000 non-null   int64
#  1   city_code      1000 non-null   int64
#  2   gender         1000 non-null   int64
#  3   age_code       1000 non-null   int64
#  4   height         1000 non-null   int64
#  5   weight         1000 non-null   int64
#  6   waist          1000 non-null   float64
#  7   eye_left       1000 non-null   float64
#  8   eye_right      1000 non-null   float64
#  9   hear_left      1000 non-null   int64
#  10  hear_right     1000 non-null   int64
#  11  systolic       991 non-null    float64
#  12  diastolic      991 non-null    float64
#  13  blood_sugar    991 non-null    float64
#  14  cholesterol    401 non-null    float64
#  15  triglycerides  401 non-null    float64
#  16  HDL            401 non-null    float64
# ...

# %% [markdown]
# ## 수축기 혈압, 이완기 혈압, 공복 혈당 그룹 산점도 그래프

# %%
systolic_data = data['systolic'] # 수축기 혈압
diastolic_data = data['diastolic'] # 이완기 혈압
blood_sugar_data = data['blood_sugar'] # 공복혈당

plt.figure(figsize=(10, 6))

plt.scatter(systolic_data, diastolic_data, color='r', edgecolor='w', label='수축기 * 이완기')
plt.scatter(systolic_data, blood_sugar_data, color='g', edgecolor='w', label='수축기 * 공복혈당')
plt.scatter(diastolic_data, blood_sugar_data, color='b', edgecolor='w', label='이완기 * 공복혈당')

plt.title('2020년 건강검진 그룹 산점도 그래프')
plt.legend() # 범례
plt.grid()
plt.xlim(40, 180)
plt.ylim(30,300)
plt.show()

# %% [markdown]
# ## 여성 키 히스토그램

# %%
data.head()
# Out:
#    year  city_code  gender  age_code  height  weight  waist  eye_left  \
# 0  2020         36       1         9     165      60   72.1       1.2
# 1  2020         27       2        13     150      65   81.0       0.8
# 2  2020         11       2        12     155      55   70.0       0.6
# 3  2020         31       1        13     160      70   90.8       1.0
# 4  2020         41       2        12     155      50   75.2       1.5
#
#    eye_right  hear_left  ...  serum   AST   ALT   GTP  smoking  drinking  \
# 0        1.5          1  ...    1.1  21.0  27.0  21.0        1         0
# 1        0.8          1  ...    0.5  18.0  15.0  15.0        1         0
# 2        0.7          1  ...    0.7  27.0  25.0   7.0        1         0
# 3        1.0          1  ...    1.2  65.0  97.0  72.0        1         0
# 4        1.2          1  ...    0.7  18.0  17.0  14.0        1         0
#
#    oral_check  dental_caries  tartar  open_date
# 0           0            NaN     NaN 2021-12-29
# ...

# %%
fe =data['gender'] == 2

# %%
female_data = data.loc[fe]
female_data.head()
# Out:
#    year  city_code  gender  age_code  height  weight  waist  eye_left  \
# 1  2020         27       2        13     150      65   81.0       0.8
# 2  2020         11       2        12     155      55   70.0       0.6
# 4  2020         41       2        12     155      50   75.2       1.5
# 8  2020         41       2        17     150      50   82.0       0.4
# 9  2020         48       2        14     150      45   71.2       0.8
#
#    eye_right  hear_left  ...  serum   AST   ALT   GTP  smoking  drinking  \
# 1        0.8          1  ...    0.5  18.0  15.0  15.0        1         0
# 2        0.7          1  ...    0.7  27.0  25.0   7.0        1         0
# 4        1.2          1  ...    0.7  18.0  17.0  14.0        1         0
# 8        0.5          2  ...    0.7  42.0  48.0  39.0        1         0
# 9        0.7          2  ...    0.6  22.0  11.0  10.0        1         0
#
#    oral_check  dental_caries  tartar  open_date
# 1           0            NaN     NaN 2021-12-29
# ...

# %%
female_data = data.loc[fe,['gender', 'height']]
female_data.head()
# Out:
#    gender  height
# 1       2     150
# 2       2     155
# 4       2     155
# 8       2     150
# 9       2     150

# %%
plt.figure(figsize=(10, 6))
# 키의 분포를 알고 싶다!!! 7개로 구간을 나누었다!
plt.hist(female_data['height'], bins=7, label='Female')
plt.title('2020년 건강검진 여성 키 히스토그램')
plt.xlim(130, 180)
plt.xlabel('키')
plt.ylabel('빈도수(frequency)')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## 남성, 여성 키 그룹 히스토그램

# %%
ma = data['gender'] == 1 # 남성은 1

# %%
male_data = data.loc[ma, ['gender', 'height']]
male_data.head()
# Out:
#    gender  height
# 0       1     165
# 3       1     160
# 5       1     185
# 6       1     165
# 7       1     160

# %%
plt.figure(figsize=(10, 6))
# alpha = 0.5 --> 투명도가 50%
plt.hist(male_data['height'], bins=7, alpha=0.5, label='남성')
plt.hist(female_data['height'], bins=7, alpha=0.5, label='여성')

plt.title('2020년 건강검진 남성, 여성 키 그룹 히스토그램')
plt.xlim(130, 195)
plt.xlabel('키')
plt.ylabel('빈도수(frequency)')

plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## 남성, 여성 키 상자수염 그래프

# %%
female_data['height'].head()
# Out:
# 1    150
# 2    155
# 4    155
# 8    150
# 9    150
# Name: height, dtype: int64

# %%
male_data['height'].head()
# Out:
# 0    165
# 3    160
# 5    185
# 6    165
# 7    160
# Name: height, dtype: int64

# %%
import numpy as np

# 배열 
height = np.array([male_data['height'], female_data['height']], dtype=object)
height
# Out:
# array([0      165
#        3      160
#        5      185
#        6      165
#        7      160
#              ...
#        991    160
#        994    160
#        995    165
#        996    165
#        999    160
#        Name: height, Length: 482, dtype: int64,
#        1      150
#        2      155
#        4      155
#        8      150
#        9      150
#              ...
#        990    150
#        992    150
#        993    145
#        997    155
#        998    150
#        Name: height, Length: 518, dtype: int64], dtype=object)

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.10.9'

# %%
plt.figure(figsize=(8, 5))
plt.boxplot(height, tick_labels=['남', '여'])

plt.ylim(130, 200)
plt.xlabel('gender')
plt.ylabel('height')
plt.title('2020년 건강검진 남성여성 키 상자수염 그래프')
plt.show()

# %% [markdown]
# ## 4.

# %%
import seaborn as sns

# %%
data3.head()
# Out:
#    city_code  gender  waist
# 0         36       1   72.1
# 1         27       2   81.0
# 2         11       2   70.0
# 3         31       1   90.8
# 4         41       2   75.2

# %%
data = pd.read_excel('health_screenings_2020_1000ea.xlsx')
data3 = data.loc[:,['city_code', 'gender', 'waist']]

male_data = data3[data3['gender'] ==1].groupby('city_code')['waist'].mean()
female_data = data3[data3['gender'] ==2].groupby('city_code')['waist'].mean()

plt.figure(figsize=(12, 4))
plt.plot(male_data, 'bo--', label='male')
plt.plot(female_data, 'ro--', label='female')

plt.xlabel('count')
plt.ylabel('waist')
plt.title('2020 Health Screenings Waist')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## 5.

# %%
waistData.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 waistData.head()
#
# NameError: name 'waistData' is not defined

# %%
data3 = data.loc[:,['city_code', 'gender', 'waist']]

waistData = data3.loc[100:110,['waist']]

plt.figure(figsize=(10, 5))

# x= 인덱스행 height=몸무게
plt.bar(waistData.index, waistData['waist'], color='c')

plt.ylim(50, 110)
plt.xlabel('Count')
plt.ylabel('Waist')
plt.title('2020 Health Screenings Waist')
plt.grid()
plt.show()

# %% [markdown]
# ## 6.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_excel('health_screenings_2020_1000ea.xlsx')
IEyedata = data['eye_left']
rEyedata = data['eye_right']

plt.figure(figsize=(5,5))
plt.scatter(IEyedata, rEyedata)

plt.xlim(0, 2.5)
plt.ylim(0, 2.5)
plt.xlabel('Eye Left')
plt.ylabel('Eye Right')
plt.title('2020 Health Screenings Scatter Graph')
plt.show()

# %% [markdown]
# ## 7.

# %%
data3 = pd.read_excel('health_screenings_2020_1000ea.xlsx')
data3 = data.loc[:,['city_code', 'gender', 'waist']]

male_data = data3.loc[data3.gender == 1, ['gender', 'waist']]
female_data = data3.loc[data3.gender == 2, ['gender', 'waist']]

plt.figure(figsize=(10, 6))
plt.hist(male_data['waist'], bins=8, alpha=0.5, label='Male')
plt.hist(female_data['waist'], bins=8, alpha=0.5, label='Female')

plt.xlim(50, 115)
plt.xlabel('Waist')
plt.ylabel('Frequency')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## 8.

# %%
mandata = data3.loc[data3.gender == 1, ['gender', 'waist']]
womandata = data3.loc[data3.gender == 2, ['gender', 'waist']]
    
male = np.array(mandata['waist'], dtype=object)
female = np.array(mandata['waist'], dtype=object)

plt.figure(figsize=(10, 5))
plt.boxplot([male, female], tick_labels=['Male', 'Female'])


plt.ylim(55,130)
plt.xlabel('Gender')
plt.ylabel('Waist')
plt.title('2020 Health Screenings Male & Female Waist Box Plot')
plt.show()

# %%
data6 = data.loc[:,['gender', 'height', 'weight', 'waist', 'drinking' 'smoking']]
data6
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 data6 = data.loc[:,['gender', 'height', 'weight', 'waist', 'drinking' 'smoking']]
#       2 data6
#
# File c:\Users\Administrator\bigdata2026\bigdata2026-basic\.venv\Lib\site-packages\pandas\core\indexing.py:1200, in _LocationIndexer.__getitem__(self, key)
#    1198     if self._is_scalar_access(key):
#    1199         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1200     return self._getitem_tuple(key)
#    1201 else:
#    1202     # we by definition only have the 0th axis
#    1203     axis = self.axis or 0
#
# File c:\Users\Administrator\bigdata2026\bigdata2026-basic\.venv\Lib\site-packages\pandas\core\indexing.py:1386, in _LocIndexer._getitem_tuple(self, tup)
#    1384 with suppress(IndexingError):
#    1385     tup = self._expand_ellipsis(tup)
# ...

# %%
data6 = data.loc[:,['gender', 'height', 'weight', 'waist', 'drinking' 'smoking']]
data6['gender'] = data6['gender'].map({1:'Male', 2:'Female'})
data6
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 data6 = data.loc[:,['gender', 'height', 'weight', 'waist', 'drinking' 'smoking']]
#       2 data6['gender'] = data6['gender'].map({1:'Male', 2:'Female'})
#       3 data6
#
# File c:\Users\Administrator\bigdata2026\bigdata2026-basic\.venv\Lib\site-packages\pandas\core\indexing.py:1200, in _LocationIndexer.__getitem__(self, key)
#    1198     if self._is_scalar_access(key):
#    1199         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1200     return self._getitem_tuple(key)
#    1201 else:
#    1202     # we by definition only have the 0th axis
#    1203     axis = self.axis or 0
#
# File c:\Users\Administrator\bigdata2026\bigdata2026-basic\.venv\Lib\site-packages\pandas\core\indexing.py:1386, in _LocIndexer._getitem_tuple(self, tup)
#    1384 with suppress(IndexingError):
# ...

# %%
data6['smoking'] = data6['drinking'].map({0:'Non-Drinking', 1:'Drinking'})

# %%
data6['smoking']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 data6['smoking']
#
# NameError: name 'data6' is not defined

# %%
data6['somking'] = data6['smoking'].map({1:'Non-smoking', 2:'Non-smoking', 3:'smoking'})
data6
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 data6['somking'] = data6['smoking'].map({1:'Non-smoking', 2:'Non-smoking', 3:'smoking'})
#       2 data6
#
# NameError: name 'data6' is not defined

# %%
smoking = data6.groupby(['gender','smoking'])['smoking'].count()
smoking =smoking.to_frame(name='count')
smoking =smoking.reset_index()

# %%
plt.figure(figsize=(10, 6))

sns.countplot(data=data6, x='smoking', hue='gender', order=['smoking', 'Non-smoking'] )

plt.title('smoking Count Plot Graph')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[81], line 3
#       1 plt.figure(figsize=(10, 6))
#       2
# ----> 3 sns.countplot(data=data6, x='smoking', hue='gender', order=['smoking', 'Non-smoking'] )
#       4
#       5 plt.title('smoking Count Plot Graph')
#       6 plt.show()
#
# NameError: name 'data6' is not defined
