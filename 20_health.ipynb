# %% [markdown]
# # 2020년 건강검진 일부 데이터 -> 산점도 그래프

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import koreanize_matplotlib

# %%
# 데이터 불러오기
data = pd.read_excel('health_screenings_2020_1000ea.xlsx')

# %%
data.shape
# Out:
# (1000, 30)

# %%
data.head()
# Out:
#    year  city_code  gender  age_code  height  weight  waist  eye_left  \
# 0  2020         36       1         9     165      60   72.1       1.2
# 1  2020         27       2        13     150      65   81.0       0.8
# 2  2020         11       2        12     155      55   70.0       0.6
# 3  2020         31       1        13     160      70   90.8       1.0
# 4  2020         41       2        12     155      50   75.2       1.5
#
#    eye_right  hear_left  ...  serum   AST   ALT   GTP  smoking  drinking  \
# 0        1.5          1  ...    1.1  21.0  27.0  21.0        1         0
# 1        0.8          1  ...    0.5  18.0  15.0  15.0        1         0
# 2        0.7          1  ...    0.7  27.0  25.0   7.0        1         0
# 3        1.0          1  ...    1.2  65.0  97.0  72.0        1         0
# 4        1.2          1  ...    0.7  18.0  17.0  14.0        1         0
#
#    oral_check  dental_caries  tartar  open_date
# 0           0            NaN     NaN 2021-12-29
# 1           0            NaN     NaN 2021-12-29
# 2           0            NaN     NaN 2021-12-29
# 3           1            0.0     0.0 2021-12-29
# 4           0            NaN     NaN 2021-12-29
#
# [5 rows x 30 columns]

# %% [markdown]
# ## 키, 몸무게 데이터를 가지고 산점도 그래프 그리기

# %%
heightdata = data['height']  # 키
weightdata = data['weight']  # 몸무게

plt.figure(figsize=(10, 4))
plt.scatter(x=heightdata, y=weightdata)

plt.title('2020년 건강검진 산점도 그래프')
plt.xlabel('키')
plt.ylabel('몸무게')
plt.grid()
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 30 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   year           1000 non-null   int64
#  1   city_code      1000 non-null   int64
#  2   gender         1000 non-null   int64
#  3   age_code       1000 non-null   int64
#  4   height         1000 non-null   int64
#  5   weight         1000 non-null   int64
#  6   waist          1000 non-null   float64
#  7   eye_left       1000 non-null   float64
#  8   eye_right      1000 non-null   float64
#  9   hear_left      1000 non-null   int64
#  10  hear_right     1000 non-null   int64
#  11  systolic       991 non-null    float64
#  12  diastolic      991 non-null    float64
#  13  blood_sugar    991 non-null    float64
#  14  cholesterol    401 non-null    float64
#  15  triglycerides  401 non-null    float64
#  16  HDL            401 non-null    float64
#  17  LDL            394 non-null    float64
#  18  hemoglobin     991 non-null    float64
#  19  urine_protein  987 non-null    float64
#  20  serum          991 non-null    float64
#  21  AST            991 non-null    float64
#  22  ALT            991 non-null    float64
#  23  GTP            991 non-null    float64
#  24  smoking        1000 non-null   int64
#  25  drinking       1000 non-null   int64
#  26  oral_check     1000 non-null   int64
#  27  dental_caries  306 non-null    float64
#  28  tartar         306 non-null    float64
#  29  open_date      1000 non-null   datetime64[us]
# dtypes: datetime64[us](1), float64(18), int64(11)
# memory usage: 234.5 KB

# %% [markdown]
# ## 수축기 혈압, 이완기 혈압, 공복 혈당 그룹 산점도 그래프

# %%
systolic_data = data['systolic'] # 수축기 혈압
diastolic_data = data['diastolic'] # 이완기 혈압
blood_sugar_data = data['blood_sugar'] # 공복혈당

plt.figure(figsize=(10, 6))

plt.scatter(systolic_data, diastolic_data, color='r', edgecolor='w', label='수축기 * 이완기')
plt.scatter(systolic_data, blood_sugar_data, color='g', edgecolor='w', label='수축기 * 공복혈당')
plt.scatter(diastolic_data, blood_sugar_data, color='b', edgecolor='w', label='이완기 * 공복혈당')

plt.title('2020년 건강검진 그룹 산점도 그래프')
plt.legend() # 범례
plt.grid()
plt.xlim(40, 180)
plt.ylim(30,300)
plt.show()

# %% [markdown]
# ## 여성 키 히스토그램

# %%
data.head()
# Out:
#    year  city_code  gender  age_code  height  weight  waist  eye_left  \
# 0  2020         36       1         9     165      60   72.1       1.2
# 1  2020         27       2        13     150      65   81.0       0.8
# 2  2020         11       2        12     155      55   70.0       0.6
# 3  2020         31       1        13     160      70   90.8       1.0
# 4  2020         41       2        12     155      50   75.2       1.5
#
#    eye_right  hear_left  ...  serum   AST   ALT   GTP  smoking  drinking  \
# 0        1.5          1  ...    1.1  21.0  27.0  21.0        1         0
# 1        0.8          1  ...    0.5  18.0  15.0  15.0        1         0
# 2        0.7          1  ...    0.7  27.0  25.0   7.0        1         0
# 3        1.0          1  ...    1.2  65.0  97.0  72.0        1         0
# 4        1.2          1  ...    0.7  18.0  17.0  14.0        1         0
#
#    oral_check  dental_caries  tartar  open_date
# 0           0            NaN     NaN 2021-12-29
# 1           0            NaN     NaN 2021-12-29
# 2           0            NaN     NaN 2021-12-29
# 3           1            0.0     0.0 2021-12-29
# 4           0            NaN     NaN 2021-12-29
#
# [5 rows x 30 columns]

# %%
fe =data['gender'] == 2

# %%
female_data = data.loc[fe]
female_data.head()
# Out:
#    year  city_code  gender  age_code  height  weight  waist  eye_left  \
# 1  2020         27       2        13     150      65   81.0       0.8
# 2  2020         11       2        12     155      55   70.0       0.6
# 4  2020         41       2        12     155      50   75.2       1.5
# 8  2020         41       2        17     150      50   82.0       0.4
# 9  2020         48       2        14     150      45   71.2       0.8
#
#    eye_right  hear_left  ...  serum   AST   ALT   GTP  smoking  drinking  \
# 1        0.8          1  ...    0.5  18.0  15.0  15.0        1         0
# 2        0.7          1  ...    0.7  27.0  25.0   7.0        1         0
# 4        1.2          1  ...    0.7  18.0  17.0  14.0        1         0
# 8        0.5          2  ...    0.7  42.0  48.0  39.0        1         0
# 9        0.7          2  ...    0.6  22.0  11.0  10.0        1         0
#
#    oral_check  dental_caries  tartar  open_date
# 1           0            NaN     NaN 2021-12-29
# 2           0            NaN     NaN 2021-12-29
# 4           0            NaN     NaN 2021-12-29
# 8           0            NaN     NaN 2021-12-29
# 9           0            NaN     NaN 2021-12-29
#
# [5 rows x 30 columns]

# %%
female_data = data.loc[fe,['gender', 'height']]
female_data.head()
# Out:
#    gender  height
# 1       2     150
# 2       2     155
# 4       2     155
# 8       2     150
# 9       2     150

# %%
plt.figure(figsize=(10, 6))
# 키의 분포를 알고 싶다!!! 7개로 구간을 나누었다!
plt.hist(female_data['height'], bins=7, label='Female')
plt.title('2020년 건강검진 여성 키 히스토그램')
plt.xlim(130, 180)
plt.xlabel('키')
plt.ylabel('빈도수(frequency)')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## 남성, 여성 키 그룹 히스토그램

# %%
ma = data['gender'] == 1 # 남성은 1

# %%
male_data = data.loc[ma, ['gender', 'height']]
male_data.head()
# Out:
#    gender  height
# 0       1     165
# 3       1     160
# 5       1     185
# 6       1     165
# 7       1     160

# %%
plt.figure(figsize=(10, 6))
# alpha = 0.5 --> 투명도가 50%
plt.hist(male_data['height'], bins=7, alpha=0.5, label='남성')
plt.hist(female_data['height'], bins=7, alpha=0.5, label='여성')

plt.title('2020년 건강검진 남성, 여성 키 그룹 히스토그램')
plt.xlim(130, 195)
plt.xlabel('키')
plt.ylabel('빈도수(frequency)')

plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## 남성, 여성 키 상자수염 그래프

# %%
female_data['height'].head()
# Out:
# 1    150
# 2    155
# 4    155
# 8    150
# 9    150
# Name: height, dtype: int64

# %%
male_data['height'].head()
# Out:
# 0    165
# 3    160
# 5    185
# 6    165
# 7    160
# Name: height, dtype: int64

# %%
import numpy as np

# 배열 
height = np.array([male_data['height'], female_data['height']], dtype=object)
height
# Out:
# array([0      165
#        3      160
#        5      185
#        6      165
#        7      160
#              ...
#        991    160
#        994    160
#        995    165
#        996    165
#        999    160
#        Name: height, Length: 482, dtype: int64,
#        1      150
#        2      155
#        4      155
#        8      150
#        9      150
#              ...
#        990    150
#        992    150
#        993    145
#        997    155
#        998    150
#        Name: height, Length: 518, dtype: int64], dtype=object)

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.10.9'

# %%
plt.figure(figsize=(8, 5))
plt.boxplot(height, tick_labels=['남', '여'])

plt.ylim(130, 200)
plt.xlabel('gender')
plt.ylabel('height')
plt.title('2020년 건강검진 남성여성 키 상자수염 그래프')
plt.show()

# %%
import seaborn as sns

# %%
data = pd.read_excel('health_screenings_2020_1000ea.xlsx')
data3 = data.loc[:,['city_code', 'gender', 'waist']]

male_data = data3[data3['gender'] ==1].groupby('city_code')['waist'].mean()
female_data = data3[data3['gender'] ==2].groupby('city_code')['waist'].mean()

plt.figure(figsize=(12, 4))
plt.plot(data3, marker='o', label='male_data')
plt.plot(data3, marker='o', label='female_data')

plt.xlabel('count')
plt.ylabel('waist')
plt.title('2020 Health Screenings Waist')
plt.legend()
plt.grid()
plt.show()

# %%
waistdata.head()
# Out:
#      waist
# 100   65.0
# 101   76.5
# 102   99.1
# 103   74.0
# 104   71.0

# %%
data3 = data.loc[:,['city_code', 'gender', 'waist']]

waistdata = data3.loc[100:110,['waist']]

plt.figure(figsize=(10, 5))

# x= 
plt.bar(waistdata.index, waistdata['waist'], color='c')

plt.ylim(50, 110)
plt.xlabel('Count')
plt.ylabel('Waist')
plt.title('2020 Health Screenings Waist')
plt.grid()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_excel('health_screenings_2020_1000ea.xlsx')
IEyedata = data['eye_left']
rEyedata = data['eye_right']

plt.figure(figsize=(5,5))
plt.scatter('IEyedata', 'rEyedata')

plt.xlim(0, 2.5)
plt.ylim(0, 2.5)
plt.xlabel('Eye Left')
plt.ylabel('Eye Right')
plt.title('2020 Health Screenings Scatter Graph')
plt.show()

# %%
data3 = pd.read_excel('health_screenings_2020_1000ea.xlsx')
data3 = data.loc[:,['city_code', 'gender', 'waist']]

male_data = data3.loc[data3.gender == 1, ['gender', 'waist']]
female_data = data3.loc[data3.gender == 2, ['gender', 'waist']]

plt.figure(figsize=(10, 6))
plt.hist(male_data['waist'], bins=7, alpha=0.5, label='Male')
plt.hist(female_data['waist'], bins=7, alpha=0.5, label='Female')

plt.xlim(50, 115)
plt.ylim(0,200)
plt.xlabel('Waist')
plt.ylabel('Frequency')
plt.legend()
plt.grid()
plt.show()

# %%
data6 = data.loc[:,['gender', 'height', 'weight', 'waist', 'drinking', 'smoking']]

data6.loc[data6['gender']==1,['gender']]='Male'
data6.loc[data6['gender']==2,['gender']]='Female'
data6.loc[(data6['smoking']==1) | (data6['smoking']==2),['smoking']]='Non-smoking' 
data6.loc[data6['smoking']==3, ['smoking']]='smoking'
    
smoking=data6.groupby(['gender', 'smoking'])['smoking'].count()
smoking=smoking.to_frame(name='count')
smoking=smoking.reset_index()

plt.figure(figsize=(10, 6))

plt.title('smoking Count Plot Graph')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# LossySetitemError                         Traceback (most recent call last)
# File c:\Users\Administrator\bigdata2026\bigdata2026-basic\.venv\Lib\site-packages\pandas\core\internals\blocks.py:1115, in Block.setitem(self, indexer, value)
#    1114 try:
# -> 1115     casted = np_can_hold_element(values.dtype, value)
#    1116 except LossySetitemError:
#    1117     # current dtype cannot store value, coerce to common dtype
#
# File c:\Users\Administrator\bigdata2026\bigdata2026-basic\.venv\Lib\site-packages\pandas\core\dtypes\cast.py:1750, in np_can_hold_element(dtype, element)
#    1748         return element
# -> 1750     raise LossySetitemError
#    1752 if dtype.kind == "f":
#
# LossySetitemError:
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[75], line 3
#       1 data6 = data.loc[:,['gender', 'height', 'weight', 'waist', 'drinking', 'smoking']]
#       2
# ----> 3 data6.loc[data6['gender']==1,['gender']]='Male'
#       4 data6.loc[data6['gender']==2,['gender']]='Female'
#       5 data6.loc[(data6['smoking']==1) | (data6['smoking']==2),['smoking']]='Non-smoking'
#       6 data6.loc[data6['smoking']==3, ['smoking']]='smoking'
#
# File c:\Users\Administrator\bigdata2026\bigdata2026-basic\.venv\Lib\site-packages\pandas\core\indexing.py:938, in _LocationIndexer.__setitem__(self, key, value)
#     933 self._has_valid_setitem_indexer(key)
#     935 iloc: _iLocIndexer = (
#     936     cast("_iLocIndexer", self) if self.name == "iloc" else self.obj.iloc
#     937 )
# --> 938 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File c:\Users\Administrator\bigdata2026\bigdata2026-basic\.venv\Lib\site-packages\pandas\core\indexing.py:1953, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1950 # align and set the values
#    1951 if take_split_path:
#    1952     # We have to operate column-wise
# -> 1953     self._setitem_with_indexer_split_path(indexer, value, name)
#    1954 else:
#    1955     self._setitem_single_block(indexer, value, name)
#
# File c:\Users\Administrator\bigdata2026\bigdata2026-basic\.venv\Lib\site-packages\pandas\core\indexing.py:2044, in _iLocIndexer._setitem_with_indexer_split_path(self, indexer, value, name)
#    2041 else:
#    2042     # scalar value
#    2043     for loc in ilocs:
# -> 2044         self._setitem_single_column(loc, value, pi)
#
# File c:\Users\Administrator\bigdata2026\bigdata2026-basic\.venv\Lib\site-packages\pandas\core\indexing.py:2181, in _iLocIndexer._setitem_single_column(self, loc, value, plane_indexer)
#    2171 if dtype == np.void:
#    2172     # This means we're expanding, with multiple columns, e.g.
#    2173     #     df = pd.DataFrame({'A': [1,2,3], 'B': [4,5,6]})
#    (...)   2176     # Here, we replace those temporary `np.void` columns with
#    2177     # columns of the appropriate dtype, based on `value`.
#    2178     self.obj.iloc[:, loc] = construct_1d_array_from_inferred_fill_value(
#    2179         value, len(self.obj)
#    2180     )
# -> 2181 self.obj._mgr.column_setitem(loc, plane_indexer, value)
#
# File c:\Users\Administrator\bigdata2026\bigdata2026-basic\.venv\Lib\site-packages\pandas\core\internals\managers.py:1528, in BlockManager.column_setitem(self, loc, idx, value, inplace_only)
#    1526     col_mgr.setitem_inplace(idx, value)
#    1527 else:
# -> 1528     new_mgr = col_mgr.setitem((idx,), value)
#    1529     self.iset(loc, new_mgr._block.values, inplace=True)
#
# File c:\Users\Administrator\bigdata2026\bigdata2026-basic\.venv\Lib\site-packages\pandas\core\internals\managers.py:607, in BaseBlockManager.setitem(self, indexer, value)
#     603     # No need to split if we either set all columns or on a single block
#     604     # manager
#     605     self = self.copy(deep=True)
# --> 607 return self.apply("setitem", indexer=indexer, value=value)
#
# File c:\Users\Administrator\bigdata2026\bigdata2026-basic\.venv\Lib\site-packages\pandas\core\internals\managers.py:445, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     443         applied = b.apply(f, **kwargs)
#     444     else:
# --> 445         applied = getattr(b, f)(**kwargs)
#     446     result_blocks = extend_blocks(applied, result_blocks)
#     448 out = type(self).from_blocks(result_blocks, [ax.view() for ax in self.axes])
#
# File c:\Users\Administrator\bigdata2026\bigdata2026-basic\.venv\Lib\site-packages\pandas\core\internals\blocks.py:1118, in Block.setitem(self, indexer, value)
#    1115     casted = np_can_hold_element(values.dtype, value)
#    1116 except LossySetitemError:
#    1117     # current dtype cannot store value, coerce to common dtype
# -> 1118     nb = self.coerce_to_target_dtype(value, raise_on_upcast=True)
#    1119     return nb.setitem(indexer, value)
#    1120 else:
#
# File c:\Users\Administrator\bigdata2026\bigdata2026-basic\.venv\Lib\site-packages\pandas\core\internals\blocks.py:468, in Block.coerce_to_target_dtype(self, other, raise_on_upcast)
#     465     raise_on_upcast = False
#     467 if raise_on_upcast:
# --> 468     raise TypeError(f"Invalid value '{other}' for dtype '{self.values.dtype}'")
#     469 if self.values.dtype == new_dtype:
#     470     raise AssertionError(
#     471         f"Did not expect new dtype {new_dtype} to equal self.dtype "
#     472         f"{self.values.dtype}. Please report a bug at "
#     473         "https://github.com/pandas-dev/pandas/issues."
#     474     )
#
# TypeError: Invalid value 'Male' for dtype 'int64'

# %%
data6['smoking']
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 995    3
# 996    2
# 997    1
# 998    1
# 999    2
# Name: smoking, Length: 1000, dtype: int64

# %%
data6['somking'] = data6['smoking'].map({1:'Non-smoking', 2:'Non-smoking', 3:'smoking'})

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=data6, x='smoking', hue='gender', )

plt.title('smoking Count Plot Graph')
plt.show()
