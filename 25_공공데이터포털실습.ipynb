# %% [markdown]
# # 대구광역시 달서구 cctv 개수 현황

# %%
import csv

with open('cctv_20250527.csv', 'rt') as f:
    buffer = csv.reader(f, delimiter=',')
    totalcctv = 0 # cctv 개수
    for i, line in enumerate(buffer):
        if i != 0:
            totalcctv += int(line[6])

# %%
buffer

# %%
totalcctv
# Out:
# 2900

# %%
import csv

with open('거제시_CCTV_20251104.csv', 'rt') as f:
    buffer = csv.reader(f, delimiter=',')
    totalcctv = 0
    for i, line in enumerate(buffer):
        if i != 0:
            totalcctv += int(line[3])

# %%
buffer

# %%
totalcctv
# Out:
# 2475

# %%
import csv

with open('거제시_CCTV_20251104.csv', 'rt') as f:
    buffer = csv.reader(f, delimiter=',')
    for i, line in enumerate(buffer):
        view = line[5]

# %%
buffer

# %%
view
# Out:
# '70도'

# %%
import csv

with open('거제시_CCTV_20251104.csv', 'rt') as f:
    buffer = csv.reader(f, delimiter=',')
    for i, line in enumerate(buffer):
        save = line[6]

# %%
buffer

# %%
save
# Out:
# '30일'
